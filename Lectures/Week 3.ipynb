# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-data-analysis/resources/0dhYG) course resource._
#
# ---

# %% [markdown]
# # Merging Dataframes

# %% [markdown]
# Last week:
# - one dimensional series object
# - two dimensional dataframe object
# - querying series or dataframe with
#     - iloc or loc attributes
#     - boolean masking (a filtering method that uses broadcasting to determine what is kept for analysis)
#
# This week:
# - reduce and process data using GroupBy and Apply
# - join datasets from multiple files together into one
# - features of pandas for statistical analysis and ML

# %% [markdown]
# ## Part 1: adding columns (joining series to dataframe)

# %%
import pandas as pd

df = pd.DataFrame([{'Name': 'Chris', 'Item Purchased': 'Sponge', 'Cost': 22.50},
                   {'Name': 'Kevyn', 'Item Purchased': 'Kitty Litter', 'Cost': 2.50},
                   {'Name': 'Filip', 'Item Purchased': 'Spoon', 'Cost': 5.00}],
                  index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5         Sponge  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0          Spoon  Filip

# %%
df['Date'] = ['December 1', 'January 1', 'mid-May']
df
# Out:
#          Cost Item Purchased   Name        Date
# Store 1  22.5         Sponge  Chris  December 1
# Store 1   2.5   Kitty Litter  Kevyn   January 1
# Store 2   5.0          Spoon  Filip     mid-May

# %%
df['Delivered'] = True
df
# Out:
#          Cost Item Purchased   Name        Date  Delivered
# Store 1  22.5         Sponge  Chris  December 1       True
# Store 1   2.5   Kitty Litter  Kevyn   January 1       True
# Store 2   5.0          Spoon  Filip     mid-May       True

# %%
df['Feedback'] = ['Positive', None, 'Negative']
df
# Out:
#          Cost Item Purchased   Name        Date  Delivered  Feedback
# Store 1  22.5         Sponge  Chris  December 1       True  Positive
# Store 1   2.5   Kitty Litter  Kevyn   January 1       True      None
# Store 2   5.0          Spoon  Filip     mid-May       True  Negative

# %%
adf = df.reset_index()
adf['Date'] = pd.Series({0: 'December 1', 2: 'mid-May'})
adf
# Out:
#      index  Cost Item Purchased   Name        Date  Delivered  Feedback
# 0  Store 1  22.5         Sponge  Chris  December 1       True  Positive
# 1  Store 1   2.5   Kitty Litter  Kevyn         NaN       True      None
# 2  Store 2   5.0          Spoon  Filip     mid-May       True  Negative

# %% [markdown]
# ## Part 2: Merge (joining dataframes)

# %% [markdown]
# When performing merge, we need to consider Set A, Set B, A and B (Venn Diagram):
# - Outter join
#     - A ∪ B
# - Inner join
#     - A ∩ B
# - Left join
#     - A
# - Right join
#     - B
# Note for left and right join, the new columns are still created but only rows from the original A or B are created for the merged df.

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
staff_df = staff_df.set_index('Name')
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])
student_df = student_df.set_index('Name')
print(staff_df.head())
print()
print(student_df.head())
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader
#
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
pd.merge(staff_df, student_df, how='inner', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='left', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='right', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director of HR          NaN
# 1  Sally  Course liasion  Engineering
# 2  James          Grader     Business

# %% [markdown]
# ### Dealing with merging conflicts
# The merge function keeps the conflict column names by adding _x for left and _y for right

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#           Location_x   Name            Role            Location_y       School
# 0       State Street  Kelly  Director of HR                   NaN          NaN
# 1  Washington Avenue  Sally  Course liasion   512 Wilson Crescent  Engineering
# 2  Washington Avenue  James          Grader  1024 Billiard Avenue     Business

# %% [markdown]
# Practice: dataframe of products and invoices

# %%
# products and invoices are already initalized.
products = pd.DataFrame([{'Product ID': 4109, 'Price': 5.0, 'Product': 'Sushi Roll'},
                        {'Product ID': 1412, 'Price': 0.5, 'Product': 'Egg'},
                        {'Product ID': 8931, 'Price': 1.5, 'Product': 'Bagel'}])
invoices = pd.DataFrame([{'Customer': 'Ali', 'Product ID': 4109, 'Quantity': 1},
                        {'Customer': 'Eric', 'Product ID': 1412, 'Quantity': 12},
                        {'Customer': 'Ande', 'Product ID': 8931, 'Quantity': 6},
                        {'Customer': 'Sam', 'Product ID': 4109, 'Quantity': 2}])
#answer
pd.merge(products, invoices, how='outer', left_on='Product ID', right_on='Product ID')# Your Code Here
#print(pd.merge(products, invoices, left_index=True, right_on='Product ID'))

#answer == correct_answer
# Out:
#    Price     Product  Product ID Customer  Quantity
# 0    5.0  Sushi Roll        4109      Ali         1
# 1    5.0  Sushi Roll        4109      Sam         2
# 2    0.5         Egg        1412     Eric        12
# 3    1.5       Bagel        8931     Ande         6

# %% [markdown]
# ### Multiple indexing and multiple columns

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])
print(staff_df)
print(student_df)
print(pd.merge(staff_df, student_df, how='inner', left_on=['First Name','Last Name'], right_on=['First Name','Last Name']))
# Out:
#   First Name   Last Name            Role
# 0      Kelly  Desjardins  Director of HR
# 1      Sally      Brooks  Course liasion
# 2      James       Wilde          Grader
#   First Name Last Name       School
# 0      James   Hammond     Business
# 1       Mike     Smith          Law
# 2      Sally    Brooks  Engineering
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %% [markdown]
# # Idiomatic Pandas: Making Code Pandorable
# - An idiomatic solution is one that has the highest readability and performance.
# - Chain indexing is a bad practice - should be avoided.
# - Method chaining can be useful however."

# %%
import pandas as pd
df = pd.read_csv('census.csv')
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
# more pandorable approach
(df.where(df['SUMLEV']==50)
    .dropna()
    .set_index(['STNAME','CTYNAME'])
    .rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'}))
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
# maybe easier to read for newbies, but less pandorable
df = df[df['SUMLEV']==50]
df.set_index(['STNAME','CTYNAME'], inplace=True)
df.rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'})
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County          50       3         6      1       1
#           Baldwin County          50       3         6      1       3
#           Barbour County          50       3         6      1       5
#           Bibb County             50       3         6      1       7
#           Blount County           50       3         6      1       9
#           Bullock County          50       3         6      1      11
#           Butler County           50       3         6      1      13
#           Calhoun County          50       3         6      1      15
#           Chambers County         50       3         6      1      17
#           Cherokee County         50       3         6      1      19
#           Chilton County          50       3         6      1      21
#           Choctaw County          50       3         6      1      23
# ...

# %% [markdown]
# Quick exercise: method chaining on df - drop any entries where 'Quantity' is 0, and rename the column 'Weight' to 'Weight(oz.)'

# %%
#print(df.head()) # df stored internally in lecture video
(df.where(df['Quantity']==0)
 .dropna()
.rename(columns={'Weight':'Weight(oz.)'}))

#solution
print(df.drop(df[df['Quantity'] == 0].index)
      .rename(columns={'Weight': 'Weight (oz.)'}))

# %% [markdown]
# ### Applying functions to get processed columns

# %%
import numpy as np
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})

# %%
df.apply(min_max, axis=1) 
# applies a function, axis is the parameter of the index to use
# to apply over all rows, set axis=1
# Out:
#                                    max       min
# STNAME    CTYNAME
# Alabama   Autauga County       55347.0   54660.0
#           Baldwin County      203709.0  183193.0
#           Barbour County       27341.0   26489.0
#           Bibb County          22861.0   22512.0
#           Blount County        57776.0   57373.0
#           Bullock County       10887.0   10606.0
#           Butler County        20944.0   20154.0
#           Calhoun County      118437.0  115620.0
#           Chambers County      34153.0   33993.0
#           Cherokee County      26084.0   25859.0
#           Chilton County       43943.0   43665.0
#           Choctaw County       13841.0   13170.0
#           Clarke County        25767.0   24675.0
#           Clay County          13880.0   13456.0
#           Cleburne County      15072.0   14921.0
#           Coffee County        51211.0   50177.0
#           Colbert County       54514.0   54354.0
#           Conecuh County       13208.0   12662.0
# ...

# %%
import numpy as np
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['max'] = np.max(data)
    row['min'] = np.min(data)
    return row
df.apply(min_max, axis=1)
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %% [markdown]
# #### using it with lambda - calculate the max of the columns, more succient than the above codes

# %%
rows = ['POPESTIMATE2010',
        'POPESTIMATE2011',
        'POPESTIMATE2012',
        'POPESTIMATE2013',
        'POPESTIMATE2014',
        'POPESTIMATE2015']
df.apply(lambda x: np.max(x[rows]), axis=1)
# Out:
# STNAME     CTYNAME
# Alabama    Autauga County         55347.0
#            Baldwin County        203709.0
#            Barbour County         27341.0
#            Bibb County            22861.0
#            Blount County          57776.0
#            Bullock County         10887.0
#            Butler County          20944.0
#            Calhoun County        118437.0
#            Chambers County        34153.0
#            Cherokee County        26084.0
#            Chilton County         43943.0
#            Choctaw County         13841.0
#            Clarke County          25767.0
#            Clay County            13880.0
#            Cleburne County        15072.0
#            Coffee County          51211.0
#            Colbert County         54514.0
#            Conecuh County         13208.0
#            Coosa County           11758.0
#            Covington County       38060.0
#            Crenshaw County        13963.0
#            Cullman County         82005.0
# ...

# %% [markdown]
# # Group by

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
# %%timeit -n 10
for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    #print('Counties in state ' + state + ' have an average population of ' + str(avg))

# Grouping by column
# without groupby, we need to take each unique state value to calculate
# the average for each state. This takes a while: executed in 3m 20s
# 2.86 s ± 56.9 ms per loop
# Out:
# 2.89 s ± 130 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
for group, frame in df.groupby('STNAME'):
    avg = np.average(frame['CENSUS2010POP'])
    #print('Counties in state ' + group + ' have an average population of ' + str(avg))
    
# doing the same operation with groupby takes much less time
# executed in 3.43s
# 74.9 ms ± 6.43 ms per loop
# Out:
# 48.3 ms ± 847 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %%
# Grouping by function
# In this example, we are grouping different state records by their first letter

df = df.set_index('STNAME')

def fun(item):
    if item[0]<'M':
        return 0
    if item[0]<'Q':
        return 1
    return 2

for group, frame in df.groupby(fun):
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing.')
# Out:
# There are 1177 records in group 0 for processing.
# There are 1134 records in group 1 for processing.
# There are 831 records in group 2 for processing.

# %%
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]

# %%
# get average quickly with aggregate and numpy average
df.groupby('STNAME').agg({'CENSUS2010POP': np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %% [markdown]
# In Class Exercise: backpacking equipment DataFrame
# Find the total weight for each category using groupby
#
# ![image.png](attachment:image.png)

# %%
print(df)
import numpy as np

def totalWeight(row):
      return row['Weight (oz.)'] * row['Quantity']
    
# Your code here
df['total weight'] = df.apply(totalWeight,axis=1)
df.groupby('Category').agg({'total weight': np.sum})

# solution
print(df.groupby('Category').apply(lambda df,a,b: sum(df[a] * df[b]), 'Weight (oz.)', 'Quantity'))

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']))
print(type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
# <class 'pandas.core.groupby.SeriesGroupBy'>

# %%
(df.set_index('STNAME').groupby(level=0)['CENSUS2010POP']
    .agg({'avg': np.average, 'sum': np.sum}))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   from ipykernel import kernelapp as app
#                                 avg       sum
# STNAME
# Alabama                71339.343284   4779736
# Alaska                 24490.724138    710231
# Arizona               426134.466667   6392017
# Arkansas               38878.906667   2915918
# California            642309.586207  37253956
# Colorado               78581.187500   5029196
# Connecticut           446762.125000   3574097
# Delaware              299311.333333    897934
# District of Columbia  601723.000000    601723
# Florida               280616.567164  18801310
# Georgia                60928.635220   9687653
# Hawaii                272060.200000   1360301
# Idaho                  35626.863636   1567582
# Illinois              125790.509804  12830632
# ...

# %%
# when given multiple parameters and columns for aggregate function
#, a nice hiearchical table is made
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
    .agg({'avg': np.average, 'sum': np.sum}))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py:4036: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                                  avg                             sum  \
#                      POPESTIMATE2010 POPESTIMATE2011 POPESTIMATE2010
# STNAME
# Alabama                 71420.313433    71658.328358         4785161
# Alaska                  24621.413793    24921.379310          714021
# Arizona                427213.866667   431248.800000         6408208
# Arkansas                38965.253333    39180.506667         2922394
# California             643691.017241   650000.586207        37334079
# Colorado                78878.968750    79991.875000         5048254
# Connecticut            447464.625000   448719.875000         3579717
# Delaware               299930.333333   302638.666667          899791
# ...

# %%
# in cases where the aggregate labels and columns names given are the same, 
#the aggregate function do not produce hiearchical columns, be mindful of that
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
    .agg({'POPESTIMATE2010': np.average, 'POPESTIMATE2011': np.sum}))

# the first result column is of average while the second is of sum,
# this is rather strange, so be careful of this behavior
# Out:
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  71420.313433          4801108
# Alaska                   24621.413793           722720
# Arizona                 427213.866667          6468732
# Arkansas                 38965.253333          2938538
# California              643691.017241         37700034
# Colorado                 78878.968750          5119480
# Connecticut             447464.625000          3589759
# Delaware                299930.333333           907916
# District of Columbia    605126.000000           620472
# Florida                 281341.641791         19105533
# Georgia                  61090.905660          9812280
# Hawaii                  272796.000000          1378227
# Idaho                    35704.227273          1584134
# Illinois                125894.598039         12861882
# Indiana                  70549.891304          6516845
# Iowa                     30815.090909          3065389
# ...

# %% [markdown]
# # Scales

# %% [markdown]
# <b>Four major scales in data science</b>
# * <b>Ratio scale</b>: evenly spaced units, +-/* are valid mathematical operations. (Height, weight)
# * <b>Interval scale</b>: units are equally spaced, but there is no true zero. (Celcius and Kelvin) Cannot do mathematical operations!
# * <b>Ordinal scale</b>: order of the units is important, but not evenly spaced. (letter grades)
# * <b>Nominal scale</b>: categorical data, there is no order (teajms of a sport)
# <br><br>
# You can use astype to specify categorical data

# %%
df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                  index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])
df.rename(columns={0: 'Grades'}, inplace=True)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
# no order categories
df['Grades'].astype('category').head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
# ordered categories
grades = df['Grades'].astype('category',
                             categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                             ordered=True)
grades.head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
grades > 'C'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
# Exercise: cast the below series to categorical with the ordering low < medium < high
s = pd.Series(['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Low'])

# Your code here
s.astype('category', categories=['Low', 'Medium', 'High'], ordered=True)
# Solution
# s.astype('category', categories=['Low', 'Medium', 'High'], ordered=True)
# Out:
# 0       Low
# 1       Low
# 2      High
# 3    Medium
# 4       Low
# 5      High
# 6       Low
# dtype: category
# Categories (3, object): [Low < Medium < High]

# %%
# Pandas function cut: takes continuous val column to bins
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df = df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg': np.average})
pd.cut(df['avg'],10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                   (11706.087, 75333.413]
# ...

# %%
# Exercise: panda cut: cut the below series into 3 bins
s = pd.Series([168, 180, 174, 190, 170, 185, 179, 181, 175, 169, 182, 177, 180, 171])

# Your code here
pd.cut(s,3)

# # Solution
# pd.cut(s, 3)

# # You can also add labels for the sizes [Small < Medium < Large].
# pd.cut(s, 3, labels=['Small', 'Medium', 'Large'])
# Out:
# 0     (167.978, 175.333]
# 1     (175.333, 182.667]
# 2     (167.978, 175.333]
# 3       (182.667, 190.0]
# 4     (167.978, 175.333]
# 5       (182.667, 190.0]
# 6     (175.333, 182.667]
# 7     (175.333, 182.667]
# 8     (167.978, 175.333]
# 9     (167.978, 175.333]
# 10    (175.333, 182.667]
# 11    (175.333, 182.667]
# 12    (175.333, 182.667]
# 13    (167.978, 175.333]
# dtype: category
# Categories (3, interval[float64]): [(167.978, 175.333] < (175.333, 182.667] < (182.667, 190.0]]

# %% [markdown]
# # Pivot Tables

# %%
#http://open.canada.ca/data/en/dataset/98f1a129-f628-4ce4-b24d-6f16bf24dd64
df = pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km) RATING  (km)  TIME (h)
# ...

# %%
df.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc=np.mean)
# Out:
# Make    BMW  CHEVROLET   FORD   KIA  MITSUBISHI  NISSAN  SMART       TESLA
# YEAR
# 2012    NaN        NaN    NaN   NaN        49.0    80.0    NaN         NaN
# 2013    NaN        NaN  107.0   NaN        49.0    80.0   35.0  280.000000
# 2014    NaN      104.0  107.0   NaN        49.0    80.0   35.0  268.333333
# 2015  125.0      104.0  107.0  81.0        49.0    80.0   35.0  320.666667
# 2016  125.0      104.0  107.0  81.0        49.0    80.0   35.0  409.700000

# %% [markdown]
# Exercise: a dataframe with price and ratings for different bikes broken down by manufactuer. Create a pivot table. that shows the mean price and mean rating for every Manufactuerer and Bike Type combination. <br></br>
# Table given, follow by my answer:
# ![image.png](attachment:image.png)

# %%
print(Bikes)

#Your code here
Bikes.pivot_table(values={'Price', 'Rating'}, index='Manufacturer', columns='Bike Type', aggfunc=np.mean)

# another approach
Bikes.pivot_table(values={'Price', 'Rating'}, index=['Manufacturer','Bike Type']))

# Given Solution
print(pd.pivot_table(Bikes, index=['Manufacturer','Bike Type']))

# %% [markdown]
# Lecture solution: </br>
# ![image.png](attachment:image.png)

# %%
df.pivot_table(
    values='(kW)',
    index='YEAR',
    columns='Make',
    aggfunc=[np.mean, np.min],
    margins=True)
# Out:
#        mean                                                             \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000
# All   125.0     104.0  107.0  81.0       49.0   80.0  35.0  345.478261
#
#                    amin                                                        \
# Make         All    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART  TESLA
# YEAR
# 2012   64.500000    NaN       NaN    NaN   NaN       49.0   80.0   NaN    NaN
# 2013  158.444444    NaN       NaN  107.0   NaN       49.0   80.0  35.0  270.0
# ...

# %% [markdown]
# # Date Functionality in Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Timestamp

# %%
pd.Timestamp('9/1/2016 10:05AM')
# Out:
# Timestamp('2016-09-01 10:05:00')

# %% [markdown]
# ### Period

# %%
pd.Period('1/2016') # the M specifies month
# Out:
# Period('2016-01', 'M')

# %%
pd.Period('3/5/2016') # the D specifies day
# Out:
# Period('2016-03-05', 'D')

# %% [markdown]
# ### DatetimeIndex

# %%
t1 = pd.Series(list('abc'), [pd.Timestamp('2016-09-01'), pd.Timestamp('2016-09-02'), pd.Timestamp('2016-09-03')])
t1
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
type(t1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### PeriodIndex

# %%
t2 = pd.Series(list('def'), [pd.Period('2016-09'), pd.Period('2016-10'), pd.Period('2016-11')])
t2
# Out:
# 2016-09    d
# 2016-10    e
# 2016-11    f
# Freq: M, dtype: object

# %%
type(t2.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %% [markdown]
# ### Converting to Datetime

# %%
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']
ts3 = pd.DataFrame(np.random.randint(10, 100, (4,2)), index=d1, columns=list('ab'))
ts3
# Out:
#                a   b
# 2 June 2013   23  70
# Aug 29, 2014  70  98
# 2015-06-26    17  66
# 7/12/16       11  62

# %%
ts3.index = pd.to_datetime(ts3.index)
ts3
# Out:
#              a   b
# 2013-06-02  23  70
# 2014-08-29  70  98
# 2015-06-26  17  66
# 2016-07-12  11  62

# %%
pd.to_datetime('4.7.12', dayfirst=True)
# Out:
# Timestamp('2012-07-04 00:00:00')

# %% [markdown]
# ### Timedeltas

# %%
pd.Timestamp('9/3/2016')-pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('9/2/2016 8:10AM') + pd.Timedelta('12D 3H')
# Out:
# Timestamp('2016-09-14 11:10:00')

# %% [markdown]
# ### Working with Dates in a Dataframe

# %%
dates = pd.date_range('10-01-2016', periods=9, freq='2W-SUN')
dates
# Out:
# DatetimeIndex(['2016-10-02', '2016-10-16', '2016-10-30', '2016-11-13',
#                '2016-11-27', '2016-12-11', '2016-12-25', '2017-01-08',
#                '2017-01-22'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
df = pd.DataFrame({'Count 1': 100 + np.random.randint(-5, 10, 9).cumsum(),
                  'Count 2': 120 + np.random.randint(-5, 10, 9)}, index=dates)
df
# Out:
#             Count 1  Count 2
# 2016-10-02      102      125
# 2016-10-16      107      116
# 2016-10-30      103      116
# 2016-11-13       99      129
# 2016-11-27      100      117
# 2016-12-11      102      119
# 2016-12-25      104      124
# 2017-01-08      100      118
# 2017-01-22      103      115

# %%
df.index.weekday_name
# Out:
# Index(['Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday',
#        'Sunday', 'Sunday'],
#       dtype='object')

# %%
df.diff()
# Out:
#             Count 1  Count 2
# 2016-10-02      NaN      NaN
# 2016-10-16      5.0     -9.0
# 2016-10-30     -4.0      0.0
# 2016-11-13     -4.0     13.0
# 2016-11-27      1.0    -12.0
# 2016-12-11      2.0      2.0
# 2016-12-25      2.0      5.0
# 2017-01-08     -4.0     -6.0
# 2017-01-22      3.0     -3.0

# %%
df.resample('M').mean()
# Out:
#             Count 1  Count 2
# 2016-10-31    104.0    119.0
# 2016-11-30     99.5    123.0
# 2016-12-31    103.0    121.5
# 2017-01-31    101.5    116.5

# %%
df['2017']
# Out:
#             Count 1  Count 2
# 2017-01-08      100      118
# 2017-01-22      103      115

# %%
df['2016-12']
# Out:
#             Count 1  Count 2
# 2016-12-11      102      119
# 2016-12-25      104      124

# %%
df['2016-12':]
# Out:
#             Count 1  Count 2
# 2016-12-11      102      119
# 2016-12-25      104      124
# 2017-01-08      100      118
# 2017-01-22      103      115

# %%
df.asfreq('W', method='ffill')
# Out:
#             Count 1  Count 2
# 2016-10-02      102      125
# 2016-10-09      102      125
# 2016-10-16      107      116
# 2016-10-23      107      116
# 2016-10-30      103      116
# 2016-11-06      103      116
# 2016-11-13       99      129
# 2016-11-20       99      129
# 2016-11-27      100      117
# 2016-12-04      100      117
# 2016-12-11      102      119
# 2016-12-18      102      119
# 2016-12-25      104      124
# 2017-01-01      104      124
# 2017-01-08      100      118
# 2017-01-15      100      118
# 2017-01-22      103      115

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.plot()
